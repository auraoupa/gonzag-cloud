# %% [markdown]
# # GONZAG cloud example

# %%
import sys
from os import getenv
import warnings
warnings.filterwarnings("ignore")

# %%
from gonzag.config import *
from gonzag.io import *
from gonzag.utils import *
from gonzag.mod2sat import *
from gonzag.bilin_mapping import *
from gonzag.spectralysis import *

# %% [markdown]
# ## Data

# %%
import xarray as xr
osn_url = 'https://ncsa.osn.xsede.org/Pangeo/pangeo-forge/swot_adac/eNATL60_surface_region_1'
dsmod = xr.open_zarr(osn_url, consolidated=True)

# %%
dsmod
# Out:
# <xarray.Dataset>
# Dimensions:        (time_counter: 2136, x: 611, y: 763)
# Coordinates:
#     depth          (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1f            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1t            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1u            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1v            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e2f            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e2t            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e2u            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e2v            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     lat            (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     lon            (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     nav_lat        (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     nav_lon        (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     time_centered  (time_counter) datetime64[ns] dask.array<chunksize=(72,), meta=np.ndarray>
#   * time_counter   (time_counter) datetime64[ns] 2010-02-01T00:30:00 ... 2010...
# Dimensions without coordinates: x, y
# Data variables:
#     fmask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     qt_oce         (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     somecrty       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sometauy       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sosaline       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sossheig       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sosstsst       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sowaflup       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sozocrtx       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sozotaux       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     tmask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     umask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     vmask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>

# %%
name_ssh_mod = 'sossheig'
name_lsm_mod = 'tmask' 
l_griddist = False

# %%
from intake import open_catalog
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean/altimetry.yaml")
dssat  = cat["al"].to_dask()

# %%
dssat
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 34340107)
# Coordinates:
#     latitude        (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     longitude       (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#   * time            (time) datetime64[ns] 2013-03-14T05:44:50.445185024 ... 2...
# Data variables:
#     cycle           (time) int16 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     dac             (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     lwe             (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     mdt             (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     ocean_tide      (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     sla_filtered    (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     sla_unfiltered  (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     track           (time) int16 dask.array<chunksize=(34340107,), meta=np.ndarray>
# Attributes:
#     Conventions:               CF-1.6
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     cdm_data_type:             Swath
#     comment:                   Sea surface height measured by altimeters refe...
#     contact:                   servicedesk.cmems@mercator-ocean.eu
#     creator_email:             servicedesk.cmems@mercator-ocean.eu
#     creator_name:              CMEMS - Sea Level Thematic Assembly Center
#     creator_url:               http://marine.copernicus.eu
#     history:                   2019-02-20T19:39:52Z: Creation
#     institution:               CLS, CNES
#     keywords:                  Oceans > Ocean Topography > Sea Surface Height
#     keywords_vocabulary:       NetCDF COARDS Climate and Forecast Standard Names
#     license:                   http://marine.copernicus.eu/web/27-service-com...
#     platform:                  Altika
#     processing_level:          L3
#     product_version:           2019
#     project:                   COPERNICUS MARINE ENVIRONMENT MONITORING SERVI...
#     references:                http://marine.copernicus.eu
#     software_version:          6.2_DUACS_DT2018_baseline
#     source:                    Altika measurements
#     ssalto_duacs_comment:      The reference mission used for the altimeter i...
#     standard_name_vocabulary:  NetCDF Climate and Forecast (CF) Metadata Conv...
#     summary:                   SSALTO/DUACS Delayed-Time Level-3 sea surface ...
#     title:                     DT Altika Global Ocean Along track SSALTO/DUAC...

# %%
name_ssh_sat='sla_unfiltered'

# %% [markdown]
# ## Time overlap between model and satellite ?
# Assume that model is less than 1 year, satellite has at least one whole year, we take the overlapping period without considering which year is this

# %%
    (date1,date2), (Nts,Ntm) = GetTimeOverlap( dssat , dsmod )
    print(' *** Time overlap between model and satellite in UNIX epoch time: it1, it2',date1,'--',date2)
# Out:
#  *** Time overlap between model and satellite in UNIX epoch time: it1, it2 2014-02-01 -- 2014-04-30

# %% [markdown]
# ## Create object `ModelGrid` containing all the model (aka _source_) 2D+T domain grid info

# %%
  
    ModelGrid = ModGrid( dsmod, date1 , date2 , dsmod, name_lsm_mod, distorded_grid=False )
# Out:
#  *** what we use to define model land-sea mask:
#     => "tmask" in dataset
#
#  *** Skipping computation of angle distortion of the model grid! ("-D" option not invoked)...
#
#  *** About model gridded (source) domain:
#      * shape =  (763, 611)
#      * horizontal resolution:  0.016657295  degrees or  1.8507920147292316  km
#      * Is this a global domain w.r.t longitude:  False
#        ==> this is a regional domain
#        ==> working in the [0:360] frame...
#      * lon_min, lon_max =  281.99 292.17
#      * lat_min, lat_max =  30.01 40.01
#      * should we pay attention to possible STRONG local distorsion in the grid:  False
#      * number of time records of interest for the interpolation to come:  2136
#        ==> time record dates: 2014-02-01 to 2014-04-30, included

# %%
SatelliteTrack = SatTrack( dssat, date1, date2, name_ssh_sat, Np=Nts, \
                              domain_bounds=ModelGrid.domain_bounds, l_0_360=ModelGrid.l360 )
# Out:
#  *** [SatTrack()] Analyzing the time vector in dataset ...
#
#  *** About satellite track (target) domain:
#      * number of time records of interest for the interpolation to come:  10236
#        ==> time record indices: 14883510 to 19033581, included
#
#        separated in 86 tracks

# %%
def process_one_track(track):
    tt = "{:02d}".format(track)
    Solution0 = Model2SatTrack( ModelGrid, name_ssh_mod, SatelliteTrack, name_ssh_sat, track )
    c1     = 'Model SSH interpolated in space (' ; c2=') and time on satellite track'
    vvar   = [ 'latitude', 'longitude', name_ssh_mod+'_np'   , name_ssh_mod+'_bl' , name_ssh_sat          , 'distance'                            ]
    vunits = [ 'deg.N'   , 'deg.E'    ,          'm'         ,     'm'            ,    'm'                ,    'km'                               ]
    vlongN = [ 'Latitude', 'Longitude', c1+'nearest-point'+c2,  c1+'bilinear'+c2  , 'Input satellite data', 'Cumulated distance from first point' ]
    iw = SaveTimeSeries( Solution0.time, \
                             nmp.array( [Solution0.lat, Solution0.lon, Solution0.ssh_mod_np,
                                         Solution0.ssh_mod, Solution0.ssh_sat, Solution0.distance] ), \
                             vvar, 'result_'+str(tt)+'.nc', time_units='',\
                             vunits=vunits, vlnm=vlongN, missing_val=rmissval )
    return Solution0

# %%
result = process_one_track(71)
# Out:
#  *** "found" distance criterion when searching for nearest point on model grid is  1.3880940110469238  km
#
#  *** Will use zoom boxes of width of 271 points for 1st attempts of nearest-point location...
#
#
#  *** Finding nearest points on source (model) grid... (rd_found_km, np_box_r = 1.3880940110469238 135 )
#       +++ Treated point: 1/120
#           ==> Sat. coordinates:     30.049 286.234
#           ==> Model nearest point:  30.05 286.241  ( 2 254 )
#       +++ Treated point: 2/120
#           ==> Sat. coordinates:     30.107 286.218
#           ==> Model nearest point:  30.106 286.225  ( 6 253 )
#       +++ Treated point: 3/120
#           ==> Sat. coordinates:     30.164 286.203
#           ==> Model nearest point:  30.162 286.208  ( 10 252 )
#       +++ Treated point: 4/120
#           ==> Sat. coordinates:     30.222 286.187
#           ==> Model nearest point:  30.219 286.191  ( 14 251 )
#       +++ Treated point: 5/120
#           ==> Sat. coordinates:     30.28 286.171
#           ==> Model nearest point:  30.275 286.174  ( 18 250 )
#       +++ Treated point: 6/120
#           ==> Sat. coordinates:     30.338 286.155
#           ==> Model nearest point:  30.331 286.157  ( 22 249 )
#       +++ Treated point: 7/120
#           ==> Sat. coordinates:     30.396 286.14
#           ==> Model nearest point:  30.401 286.14  ( 27 248 )
#       +++ Treated point: 8/120
#           ==> Sat. coordinates:     30.454 286.124
#           ==> Model nearest point:  30.457 286.123  ( 31 247 )
#       +++ Treated point: 9/120
#           ==> Sat. coordinates:     30.511 286.108
#           ==> Model nearest point:  30.513 286.106  ( 35 246 )
#       +++ Treated point: 10/120
#           ==> Sat. coordinates:     30.569 286.092
#           ==> Model nearest point:  30.569 286.089  ( 39 245 )
#       +++ Treated point: 11/120
#           ==> Sat. coordinates:     30.627 286.077
#           ==> Model nearest point:  30.625 286.073  ( 43 244 )
#       +++ Treated point: 12/120
#           ==> Sat. coordinates:     30.685 286.061
#           ==> Model nearest point:  30.681 286.056  ( 47 243 )
#       +++ Treated point: 13/120
#           ==> Sat. coordinates:     30.743 286.045
#           ==> Model nearest point:  30.737 286.039  ( 51 242 )
#       +++ Treated point: 14/120
#           ==> Sat. coordinates:     30.801 286.029
#           ==> Model nearest point:  30.806 286.022  ( 56 241 )
#       +++ Treated point: 15/120
#           ==> Sat. coordinates:     30.859 286.013
#           ==> Model nearest point:  30.862 286.021  ( 60 241 )
#       +++ Treated point: 16/120
#           ==> Sat. coordinates:     30.916 285.997
#           ==> Model nearest point:  30.918 286.005  ( 64 240 )
#       +++ Treated point: 17/120
#           ==> Sat. coordinates:     30.974 285.982
#           ==> Model nearest point:  30.973 285.988  ( 68 239 )
#       +++ Treated point: 18/120
#           ==> Sat. coordinates:     31.032 285.966
#           ==> Model nearest point:  31.029 285.971  ( 72 238 )
#       +++ Treated point: 19/120
#           ==> Sat. coordinates:     31.09 285.95
#           ==> Model nearest point:  31.084 285.954  ( 76 237 )
#       +++ Treated point: 20/120
#           ==> Sat. coordinates:     31.148 285.934
#           ==> Model nearest point:  31.154 285.937  ( 81 236 )
#       +++ Treated point: 21/120
#           ==> Sat. coordinates:     31.206 285.918
#           ==> Model nearest point:  31.209 285.92  ( 85 235 )
#       +++ Treated point: 22/120
#           ==> Sat. coordinates:     31.263 285.902
#           ==> Model nearest point:  31.264 285.903  ( 89 234 )
#       +++ Treated point: 23/120
#           ==> Sat. coordinates:     31.321 285.886
#           ==> Model nearest point:  31.319 285.886  ( 93 233 )
#       +++ Treated point: 24/120
#           ==> Sat. coordinates:     31.379 285.87
#           ==> Model nearest point:  31.375 285.869  ( 97 232 )
#       +++ Treated point: 25/120
#           ==> Sat. coordinates:     31.437 285.854
#           ==> Model nearest point:  31.444 285.852  ( 102 231 )
#       +++ Treated point: 26/120
#           ==> Sat. coordinates:     31.495 285.838
#           ==> Model nearest point:  31.499 285.835  ( 106 230 )
#       +++ Treated point: 27/120
#           ==> Sat. coordinates:     31.552 285.822
#           ==> Model nearest point:  31.554 285.818  ( 110 229 )
#       +++ Treated point: 28/120
#           ==> Sat. coordinates:     31.61 285.806
#           ==> Model nearest point:  31.609 285.801  ( 114 228 )
#       +++ Treated point: 29/120
#           ==> Sat. coordinates:     31.668 285.79
#           ==> Model nearest point:  31.664 285.784  ( 118 227 )
#       +++ Treated point: 30/120
#           ==> Sat. coordinates:     31.726 285.774
#           ==> Model nearest point:  31.732 285.767  ( 123 226 )
#       +++ Treated point: 31/120
#           ==> Sat. coordinates:     31.784 285.758
#           ==> Model nearest point:  31.787 285.75  ( 127 225 )
#       +++ Treated point: 32/120
#           ==> Sat. coordinates:     31.842 285.742
#           ==> Model nearest point:  31.842 285.75  ( 131 225 )
#       +++ Treated point: 33/120
#           ==> Sat. coordinates:     31.899 285.725
#           ==> Model nearest point:  31.897 285.733  ( 135 224 )
#       +++ Treated point: 34/120
#           ==> Sat. coordinates:     31.957 285.709
#           ==> Model nearest point:  31.952 285.716  ( 139 223 )
#       +++ Treated point: 35/120
#           ==> Sat. coordinates:     32.015 285.693
#           ==> Model nearest point:  32.02 285.699  ( 144 222 )
#       +++ Treated point: 36/120
#           ==> Sat. coordinates:     32.073 285.677
#           ==> Model nearest point:  32.074 285.682  ( 148 221 )
#       +++ Treated point: 37/120
#           ==> Sat. coordinates:     32.131 285.661
#           ==> Model nearest point:  32.129 285.664  ( 152 220 )
#       +++ Treated point: 38/120
#           ==> Sat. coordinates:     32.188 285.645
#           ==> Model nearest point:  32.183 285.647  ( 156 219 )
#       +++ Treated point: 39/120
#           ==> Sat. coordinates:     32.246 285.628
#           ==> Model nearest point:  32.251 285.63  ( 161 218 )
#       +++ Treated point: 40/120
#           ==> Sat. coordinates:     32.304 285.612
#           ==> Model nearest point:  32.306 285.613  ( 165 217 )
#       +++ Treated point: 41/120
#           ==> Sat. coordinates:     32.362 285.596
#           ==> Model nearest point:  32.36 285.596  ( 169 216 )
#       +++ Treated point: 42/120
#           ==> Sat. coordinates:     32.42 285.58
#           ==> Model nearest point:  32.414 285.579  ( 173 215 )
#       +++ Treated point: 43/120
#           ==> Sat. coordinates:     32.477 285.564
#           ==> Model nearest point:  32.482 285.562  ( 178 214 )
#       +++ Treated point: 44/120
#           ==> Sat. coordinates:     32.535 285.547
#           ==> Model nearest point:  32.536 285.545  ( 182 213 )
#       +++ Treated point: 45/120
#           ==> Sat. coordinates:     32.593 285.531
#           ==> Model nearest point:  32.59 285.528  ( 186 212 )
#       +++ Treated point: 46/120
#           ==> Sat. coordinates:     32.651 285.515
#           ==> Model nearest point:  32.644 285.511  ( 190 211 )
#       +++ Treated point: 47/120
#           ==> Sat. coordinates:     32.708 285.498
#           ==> Model nearest point:  32.712 285.494  ( 195 210 )
#       +++ Treated point: 48/120
#           ==> Sat. coordinates:     32.766 285.482
#           ==> Model nearest point:  32.766 285.477  ( 199 209 )
#       +++ Treated point: 49/120
#           ==> Sat. coordinates:     32.824 285.466
#           ==> Model nearest point:  32.82 285.46  ( 203 208 )
#       +++ Treated point: 50/120
#           ==> Sat. coordinates:     32.882 285.449
#           ==> Model nearest point:  32.887 285.442  ( 208 207 )
#       +++ Treated point: 51/120
#           ==> Sat. coordinates:     32.94 285.433
#           ==> Model nearest point:  32.941 285.425  ( 212 206 )
#       +++ Treated point: 52/120
#           ==> Sat. coordinates:     32.997 285.416
#           ==> Model nearest point:  32.994 285.408  ( 216 205 )
#       +++ Treated point: 53/120
#           ==> Sat. coordinates:     33.055 285.4
#           ==> Model nearest point:  33.061 285.408  ( 221 205 )
#       +++ Treated point: 54/120
#           ==> Sat. coordinates:     33.113 285.384
#           ==> Model nearest point:  33.115 285.39  ( 225 204 )
#       +++ Treated point: 55/120
#           ==> Sat. coordinates:     33.171 285.367
#           ==> Model nearest point:  33.169 285.373  ( 229 203 )
#       +++ Treated point: 56/120
#           ==> Sat. coordinates:     33.228 285.351
#           ==> Model nearest point:  33.222 285.356  ( 233 202 )
#       +++ Treated point: 57/120
#           ==> Sat. coordinates:     33.286 285.334
#           ==> Model nearest point:  33.289 285.339  ( 238 201 )
#       +++ Treated point: 58/120
#           ==> Sat. coordinates:     33.344 285.318
#           ==> Model nearest point:  33.342 285.322  ( 242 200 )
#       +++ Treated point: 59/120
#           ==> Sat. coordinates:     33.402 285.301
#           ==> Model nearest point:  33.396 285.305  ( 246 199 )
#       +++ Treated point: 60/120
#           ==> Sat. coordinates:     33.459 285.285
#           ==> Model nearest point:  33.462 285.287  ( 251 198 )
#       +++ Treated point: 61/120
#           ==> Sat. coordinates:     33.517 285.268
#           ==> Model nearest point:  33.515 285.27  ( 255 197 )
#       +++ Treated point: 62/120
#           ==> Sat. coordinates:     33.575 285.252
#           ==> Model nearest point:  33.568 285.253  ( 259 196 )
#       +++ Treated point: 63/120
#           ==> Sat. coordinates:     33.633 285.235
#           ==> Model nearest point:  33.635 285.236  ( 264 195 )
#       +++ Treated point: 64/120
#           ==> Sat. coordinates:     33.691 285.218
#           ==> Model nearest point:  33.688 285.219  ( 268 194 )
#       +++ Treated point: 65/120
#           ==> Sat. coordinates:     33.748 285.202
#           ==> Model nearest point:  33.754 285.201  ( 273 193 )
#       +++ Treated point: 66/120
#           ==> Sat. coordinates:     33.806 285.185
#           ==> Model nearest point:  33.807 285.184  ( 277 192 )
#       +++ Treated point: 67/120
#           ==> Sat. coordinates:     33.864 285.168
#           ==> Model nearest point:  33.86 285.167  ( 281 191 )
#       +++ Treated point: 68/120
#           ==> Sat. coordinates:     33.922 285.152
#           ==> Model nearest point:  33.926 285.15  ( 286 190 )
#       +++ Treated point: 69/120
#           ==> Sat. coordinates:     33.979 285.135
#           ==> Model nearest point:  33.978 285.132  ( 290 189 )
#       +++ Treated point: 70/120
#           ==> Sat. coordinates:     34.037 285.118
#           ==> Model nearest point:  34.031 285.115  ( 294 188 )
#       +++ Treated point: 71/120
#           ==> Sat. coordinates:     34.095 285.102
#           ==> Model nearest point:  34.097 285.098  ( 299 187 )
#       +++ Treated point: 72/120
#           ==> Sat. coordinates:     34.152 285.085
#           ==> Model nearest point:  34.149 285.081  ( 303 186 )
#       +++ Treated point: 73/120
#           ==> Sat. coordinates:     34.21 285.068
#           ==> Model nearest point:  34.215 285.063  ( 308 185 )
#       +++ Treated point: 74/120
#           ==> Sat. coordinates:     34.268 285.051
#           ==> Model nearest point:  34.267 285.046  ( 312 184 )
#       +++ Treated point: 75/120
#           ==> Sat. coordinates:     34.326 285.035
#           ==> Model nearest point:  34.32 285.029  ( 316 183 )
#       +++ Treated point: 76/120
#           ==> Sat. coordinates:     34.383 285.018
#           ==> Model nearest point:  34.385 285.011  ( 321 182 )
#       +++ Treated point: 77/120
#           ==> Sat. coordinates:     34.441 285.001
#           ==> Model nearest point:  34.438 284.994  ( 325 181 )
#       +++ Treated point: 78/120
#           ==> Sat. coordinates:     34.499 284.984
#           ==> Model nearest point:  34.503 284.977  ( 330 180 )
#       +++ Treated point: 79/120
#           ==> Sat. coordinates:     34.557 284.967
#           ==> Model nearest point:  34.555 284.959  ( 334 179 )
#       +++ Treated point: 80/120
#           ==> Sat. coordinates:     34.614 284.95
#           ==> Model nearest point:  34.62 284.958  ( 339 179 )
#       +++ Treated point: 81/120
#           ==> Sat. coordinates:     34.672 284.933
#           ==> Model nearest point:  34.672 284.941  ( 343 178 )
#       +++ Treated point: 82/120
#           ==> Sat. coordinates:     34.73 284.917
#           ==> Model nearest point:  34.724 284.924  ( 347 177 )
#       +++ Treated point: 83/120
#           ==> Sat. coordinates:     34.787 284.9
#           ==> Model nearest point:  34.789 284.906  ( 352 176 )
#       +++ Treated point: 84/120
#           ==> Sat. coordinates:     34.845 284.883
#           ==> Model nearest point:  34.841 284.889  ( 356 175 )
#       +++ Treated point: 85/120
#           ==> Sat. coordinates:     34.903 284.866
#           ==> Model nearest point:  34.906 284.872  ( 361 174 )
#       +++ Treated point: 86/120
#           ==> Sat. coordinates:     34.961 284.849
#           ==> Model nearest point:  34.957 284.854  ( 365 173 )
#       +++ Treated point: 87/120
#           ==> Sat. coordinates:     35.018 284.832
#           ==> Model nearest point:  35.022 284.837  ( 370 172 )
#       +++ Treated point: 88/120
#           ==> Sat. coordinates:     35.076 284.815
#           ==> Model nearest point:  35.074 284.819  ( 374 171 )
#       +++ Treated point: 89/120
#           ==> Sat. coordinates:     35.134 284.798
#           ==> Model nearest point:  35.138 284.802  ( 379 170 )
#       +++ Treated point: 90/120
#           ==> Sat. coordinates:     35.307 284.746
#           ==> Model nearest point:  35.305 284.749  ( 392 167 )
#       +++ Treated point: 91/120
#           ==> Sat. coordinates:     35.365 284.729
#           ==> Model nearest point:  35.369 284.732  ( 397 166 )
#       +++ Treated point: 92/120
#           ==> Sat. coordinates:     35.422 284.712
#           ==> Model nearest point:  35.42 284.715  ( 401 165 )
#       +++ Treated point: 93/120
#           ==> Sat. coordinates:     35.48 284.695
#           ==> Model nearest point:  35.484 284.697  ( 406 164 )
#       +++ Treated point: 94/120
#           ==> Sat. coordinates:     35.538 284.678
#           ==> Model nearest point:  35.536 284.68  ( 410 163 )
#       +++ Treated point: 95/120
#           ==> Sat. coordinates:     35.595 284.661
#           ==> Model nearest point:  35.599 284.662  ( 415 162 )
#       +++ Treated point: 96/120
#           ==> Sat. coordinates:     35.653 284.644
#           ==> Model nearest point:  35.65 284.644  ( 419 161 )
#       +++ Treated point: 97/120
#           ==> Sat. coordinates:     35.711 284.626
#           ==> Model nearest point:  35.714 284.627  ( 424 160 )
#       +++ Treated point: 98/120
#           ==> Sat. coordinates:     35.768 284.609
#           ==> Model nearest point:  35.765 284.609  ( 428 159 )
#       +++ Treated point: 99/120
#           ==> Sat. coordinates:     35.826 284.592
#           ==> Model nearest point:  35.828 284.592  ( 433 158 )
#       +++ Treated point: 100/120
#           ==> Sat. coordinates:     35.884 284.574
#           ==> Model nearest point:  35.879 284.574  ( 437 157 )
#       +++ Treated point: 101/120
#           ==> Sat. coordinates:     35.941 284.557
#           ==> Model nearest point:  35.943 284.557  ( 442 156 )
#       +++ Treated point: 102/120
#           ==> Sat. coordinates:     35.999 284.54
#           ==> Model nearest point:  35.993 284.539  ( 446 155 )
#       +++ Treated point: 103/120
#           ==> Sat. coordinates:     36.057 284.523
#           ==> Model nearest point:  36.056 284.521  ( 451 154 )
#       +++ Treated point: 104/120
#           ==> Sat. coordinates:     36.114 284.505
#           ==> Model nearest point:  36.12 284.504  ( 456 153 )
#       +++ Treated point: 105/120
#           ==> Sat. coordinates:     36.172 284.488
#           ==> Model nearest point:  36.17 284.486  ( 460 152 )
#       +++ Treated point: 106/120
#           ==> Sat. coordinates:     36.23 284.47
#           ==> Model nearest point:  36.233 284.468  ( 465 151 )
#       +++ Treated point: 107/120
#           ==> Sat. coordinates:     36.287 284.453
#           ==> Model nearest point:  36.283 284.451  ( 469 150 )
#       +++ Treated point: 108/120
#           ==> Sat. coordinates:     36.345 284.436
#           ==> Model nearest point:  36.346 284.433  ( 474 149 )
#       +++ Treated point: 109/120
#           ==> Sat. coordinates:     36.403 284.418
#           ==> Model nearest point:  36.409 284.415  ( 479 148 )
#       +++ Treated point: 110/120
#           ==> Sat. coordinates:     36.46 284.401
#           ==> Model nearest point:  36.459 284.398  ( 483 147 )
#       +++ Treated point: 111/120
#           ==> Sat. coordinates:     36.518 284.383
#           ==> Model nearest point:  36.522 284.38  ( 488 146 )
#       +++ Treated point: 112/120
#           ==> Sat. coordinates:     36.576 284.366
#           ==> Model nearest point:  36.572 284.362  ( 492 145 )
#       +++ Treated point: 113/120
#           ==> Sat. coordinates:     36.633 284.348
#           ==> Model nearest point:  36.634 284.344  ( 497 144 )
#       +++ Treated point: 114/120
#           ==> Sat. coordinates:     36.691 284.331
#           ==> Model nearest point:  36.696 284.327  ( 502 143 )
#       +++ Treated point: 115/120
#           ==> Sat. coordinates:     36.749 284.313
#           ==> Model nearest point:  36.746 284.309  ( 506 142 )
#       +++ Treated point: 116/120
#           ==> Sat. coordinates:     36.806 284.295
#           ==> Model nearest point:  36.808 284.291  ( 511 141 )
#       +++ Treated point: 117/120
#           ==> Sat. coordinates:     36.864 284.278
#           ==> Model nearest point:  36.858 284.274  ( 515 140 )
#       +++ Treated point: 118/120
#           ==> Sat. coordinates:     36.922 284.26
#           ==> Model nearest point:  36.92 284.256  ( 520 139 )
#       +++ Treated point: 119/120
#           ==> Sat. coordinates:     36.979 284.242
#           ==> Model nearest point:  36.982 284.238  ( 525 138 )
#       +++ Treated point: 120/120
#           ==> Sat. coordinates:     37.037 284.225
#           ==> Model nearest point:  37.032 284.22  ( 529 137 )
#      ***    Done! ***
#
#   *** Determining source meshes...
#      ***    Done! ***
#
#   *** Computing bilinear weights...
#      ***    Done! ***
#
#
#  *** Starting space-time interpolation of model data onto the 120 selected track points...
#       jt = 09029 => satelite time = 2014-04-20T10:39:17.001146880
#       jt = 09030 => satelite time = 2014-04-20T10:39:17.981146880
#       jt = 09031 => satelite time = 2014-04-20T10:39:18.961146880
#       jt = 09032 => satelite time = 2014-04-20T10:39:19.941146880
#       jt = 09033 => satelite time = 2014-04-20T10:39:20.921146880
#       jt = 09034 => satelite time = 2014-04-20T10:39:21.901146880
#       jt = 09035 => satelite time = 2014-04-20T10:39:22.881146880
#       jt = 09036 => satelite time = 2014-04-20T10:39:23.861146880
#       jt = 09037 => satelite time = 2014-04-20T10:39:24.841146880
#       jt = 09038 => satelite time = 2014-04-20T10:39:25.821146880
#       jt = 09039 => satelite time = 2014-04-20T10:39:26.801146880
#       jt = 09040 => satelite time = 2014-04-20T10:39:27.781146880
#       jt = 09041 => satelite time = 2014-04-20T10:39:28.761146880
#       jt = 09042 => satelite time = 2014-04-20T10:39:29.741146880
#       jt = 09043 => satelite time = 2014-04-20T10:39:30.721146880
#       jt = 09044 => satelite time = 2014-04-20T10:39:31.701146880
#       jt = 09045 => satelite time = 2014-04-20T10:39:32.681146880
#       jt = 09046 => satelite time = 2014-04-20T10:39:33.661146880
#       jt = 09047 => satelite time = 2014-04-20T10:39:34.641146880
#       jt = 09048 => satelite time = 2014-04-20T10:39:35.621146880
#       jt = 09049 => satelite time = 2014-04-20T10:39:36.601146880
#       jt = 09050 => satelite time = 2014-04-20T10:39:37.581146880
#       jt = 09051 => satelite time = 2014-04-20T10:39:38.561146880
#       jt = 09052 => satelite time = 2014-04-20T10:39:39.541146880
#       jt = 09053 => satelite time = 2014-04-20T10:39:40.521146880
#       jt = 09054 => satelite time = 2014-04-20T10:39:41.501146880
#       jt = 09055 => satelite time = 2014-04-20T10:39:42.481146880
#       jt = 09056 => satelite time = 2014-04-20T10:39:43.461146880
#       jt = 09057 => satelite time = 2014-04-20T10:39:44.441146880
#       jt = 09058 => satelite time = 2014-04-20T10:39:45.421146880
#       jt = 09059 => satelite time = 2014-04-20T10:39:46.401146880
#       jt = 09060 => satelite time = 2014-04-20T10:39:47.381146880
#       jt = 09061 => satelite time = 2014-04-20T10:39:48.361146880
#       jt = 09062 => satelite time = 2014-04-20T10:39:49.341146880
#       jt = 09063 => satelite time = 2014-04-20T10:39:50.321146880
#       jt = 09064 => satelite time = 2014-04-20T10:39:51.301146880
#       jt = 09065 => satelite time = 2014-04-20T10:39:52.281146880
#       jt = 09066 => satelite time = 2014-04-20T10:39:53.261146880
#       jt = 09067 => satelite time = 2014-04-20T10:39:54.241146880
#       jt = 09068 => satelite time = 2014-04-20T10:39:55.221146880
#       jt = 09069 => satelite time = 2014-04-20T10:39:56.201146880
#       jt = 09070 => satelite time = 2014-04-20T10:39:57.181146880
#       jt = 09071 => satelite time = 2014-04-20T10:39:58.161146880
#       jt = 09072 => satelite time = 2014-04-20T10:39:59.141146880
#       jt = 09073 => satelite time = 2014-04-20T10:40:00.121146880
#       jt = 09074 => satelite time = 2014-04-20T10:40:01.101146880
#       jt = 09075 => satelite time = 2014-04-20T10:40:02.081146880
#       jt = 09076 => satelite time = 2014-04-20T10:40:03.061146880
#       jt = 09077 => satelite time = 2014-04-20T10:40:04.041146880
#       jt = 09078 => satelite time = 2014-04-20T10:40:05.021146880
#       jt = 09079 => satelite time = 2014-04-20T10:40:06.001146880
#       jt = 09080 => satelite time = 2014-04-20T10:40:06.981146880
#       jt = 09081 => satelite time = 2014-04-20T10:40:07.961146880
#       jt = 09082 => satelite time = 2014-04-20T10:40:08.941146880
#       jt = 09083 => satelite time = 2014-04-20T10:40:09.921146880
#       jt = 09084 => satelite time = 2014-04-20T10:40:10.901146880
#       jt = 09085 => satelite time = 2014-04-20T10:40:11.881146880
#       jt = 09086 => satelite time = 2014-04-20T10:40:12.861146880
#       jt = 09087 => satelite time = 2014-04-20T10:40:13.841146880
#       jt = 09088 => satelite time = 2014-04-20T10:40:14.821146880
#       jt = 09089 => satelite time = 2014-04-20T10:40:15.801146880
#       jt = 09090 => satelite time = 2014-04-20T10:40:16.781146880
#       jt = 09091 => satelite time = 2014-04-20T10:40:17.761146880
#       jt = 09092 => satelite time = 2014-04-20T10:40:18.741146880
#       jt = 09093 => satelite time = 2014-04-20T10:40:19.721146880
#       jt = 09094 => satelite time = 2014-04-20T10:40:20.701146880
#       jt = 09095 => satelite time = 2014-04-20T10:40:21.681146880
#       jt = 09096 => satelite time = 2014-04-20T10:40:22.661146880
#       jt = 09097 => satelite time = 2014-04-20T10:40:23.641146880
#       jt = 09098 => satelite time = 2014-04-20T10:40:24.621146880
#       jt = 09099 => satelite time = 2014-04-20T10:40:25.601146880
#       jt = 09100 => satelite time = 2014-04-20T10:40:26.581146880
#       jt = 09101 => satelite time = 2014-04-20T10:40:27.561146880
#       jt = 09102 => satelite time = 2014-04-20T10:40:28.541146880
#       jt = 09103 => satelite time = 2014-04-20T10:40:29.521146880
#       jt = 09104 => satelite time = 2014-04-20T10:40:30.501146880
#       jt = 09105 => satelite time = 2014-04-20T10:40:31.481146880
#       jt = 09106 => satelite time = 2014-04-20T10:40:32.461146880
#       jt = 09107 => satelite time = 2014-04-20T10:40:33.441146880
#       jt = 09108 => satelite time = 2014-04-20T10:40:34.421146880
#       jt = 09109 => satelite time = 2014-04-20T10:40:35.401146880
#       jt = 09110 => satelite time = 2014-04-20T10:40:36.381146880
#       jt = 09111 => satelite time = 2014-04-20T10:40:37.361146880
#       jt = 09112 => satelite time = 2014-04-20T10:40:38.341146880
#       jt = 09113 => satelite time = 2014-04-20T10:40:39.321146880
#       jt = 09114 => satelite time = 2014-04-20T10:40:40.301146880
#       jt = 09115 => satelite time = 2014-04-20T10:40:41.281146880
#       jt = 09116 => satelite time = 2014-04-20T10:40:42.261146880
#       jt = 09117 => satelite time = 2014-04-20T10:40:43.241146880
#       jt = 09118 => satelite time = 2014-04-20T10:40:46.181146880
#       jt = 09119 => satelite time = 2014-04-20T10:40:47.161146880
#       jt = 09120 => satelite time = 2014-04-20T10:40:48.141146880
#       jt = 09121 => satelite time = 2014-04-20T10:40:49.121146880
#       jt = 09122 => satelite time = 2014-04-20T10:40:50.101146880
#       jt = 09123 => satelite time = 2014-04-20T10:40:51.081146880
#       jt = 09124 => satelite time = 2014-04-20T10:40:52.061146880
#       jt = 09125 => satelite time = 2014-04-20T10:40:53.041146880
#       jt = 09126 => satelite time = 2014-04-20T10:40:54.021146880
#       jt = 09127 => satelite time = 2014-04-20T10:40:55.001146880
#       jt = 09128 => satelite time = 2014-04-20T10:40:55.981146880
#       jt = 09129 => satelite time = 2014-04-20T10:40:56.961146880
#       jt = 09130 => satelite time = 2014-04-20T10:40:57.941146880
#       jt = 09131 => satelite time = 2014-04-20T10:40:58.921146880
#       jt = 09132 => satelite time = 2014-04-20T10:40:59.901146880
#       jt = 09133 => satelite time = 2014-04-20T10:41:00.881146880
#       jt = 09134 => satelite time = 2014-04-20T10:41:01.861146880
#       jt = 09135 => satelite time = 2014-04-20T10:41:02.841146880
#       jt = 09136 => satelite time = 2014-04-20T10:41:03.821146880
#       jt = 09137 => satelite time = 2014-04-20T10:41:04.801146880
#       jt = 09138 => satelite time = 2014-04-20T10:41:05.781146880
#       jt = 09139 => satelite time = 2014-04-20T10:41:06.761146880
#       jt = 09140 => satelite time = 2014-04-20T10:41:07.741146880
#       jt = 09141 => satelite time = 2014-04-20T10:41:08.721146880
#       jt = 09142 => satelite time = 2014-04-20T10:41:09.701146880
#       jt = 09143 => satelite time = 2014-04-20T10:41:10.681146880
#       jt = 09144 => satelite time = 2014-04-20T10:41:11.661146880
#       jt = 09145 => satelite time = 2014-04-20T10:41:12.641146880
#       jt = 09146 => satelite time = 2014-04-20T10:41:13.621146880
#       jt = 09147 => satelite time = 2014-04-20T10:41:14.601146880
#       jt = 09148 => satelite time = 2014-04-20T10:41:15.581146880
#  *** Space-time interpolation done!
#
#
#  *** Time report:
#      - Construction of the source-target bilinear mapping took: 2.0 s
#      - Interpolation of model data on the 120 satellite points took: 199.0 s
#
#
#  *** About to write file "result_71.nc"...
#  *** "result_71.nc" successfully written!

# %%
result.ssh_sat
# Out:
# masked_array(data=[-0.181, -0.15 , -0.079, -0.097, -0.081, -0.094, -0.088,
#                    -0.073, -0.091, -0.108, -0.083, -0.067, -0.079, -0.069,
#                    -0.082, -0.13 , -0.143, -0.078, -0.086, -0.071, -0.075,
#                    -0.034, -0.015, -0.042, -0.058, -0.046, -0.048, -0.058,
#                    -0.033, -0.034, -0.035,  0.03 ,  0.014, -0.03 ,  0.013,
#                     0.036,  0.027,  0.018,  0.011, -0.01 , -0.004,  0.01 ,
#                     0.028,  0.   ,  0.005, -0.017, -0.051, -0.063, -0.063,
#                    -0.066, -0.063, -0.036, -0.027, -0.016, -0.025, -0.01 ,
#                    -0.03 , -0.006, -0.042, -0.048, -0.053, -0.056, -0.07 ,
#                    -0.089, -0.107, -0.111, -0.096, -0.082, -0.058, -0.028,
#                    -0.029,  0.009,  0.021,  0.018,  0.022,  0.054,  0.043,
#                     0.002, -0.001,  0.014,  0.01 , -0.034, -0.069, -0.097,
#                    -0.139, -0.197, -0.246, -0.281, -0.344, -0.418, -0.496,
#                    -0.558, -0.597, -0.645, -0.637, -0.703, -0.678, -0.655,
#                    -0.617, -0.554, -0.466, -0.403, -0.338, -0.259, -0.216,
#                    -0.213, -0.213, -0.14 , -0.133, -0.165, -0.117, -0.138,
#                    -0.166, -0.15 , -0.181, -0.174, -0.172, -0.189, -0.202,
#                    -0.193],
#              mask=False,
#        fill_value=1e+20)
