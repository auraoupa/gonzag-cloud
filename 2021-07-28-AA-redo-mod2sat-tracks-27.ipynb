# %% [markdown]
# # GONZAG cloud example

# %%
import sys
from os import getenv
import warnings
warnings.filterwarnings("ignore")

# %%
from gonzag.config import *
from gonzag.io import *
from gonzag.utils import *
from gonzag.mod2sat import *
from gonzag.bilin_mapping import *
from gonzag.spectralysis import *

# %% [markdown]
# ## Data

# %%
import xarray as xr
osn_url = 'https://ncsa.osn.xsede.org/Pangeo/pangeo-forge/swot_adac/eNATL60_surface_region_1'
dsmod = xr.open_zarr(osn_url, consolidated=True)

# %%
dsmod
# Out:
# <xarray.Dataset>
# Dimensions:        (time_counter: 2136, x: 611, y: 763)
# Coordinates:
#     depth          (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1f            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1t            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1u            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1v            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e2f            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e2t            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e2u            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e2v            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     lat            (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     lon            (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     nav_lat        (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     nav_lon        (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     time_centered  (time_counter) datetime64[ns] dask.array<chunksize=(72,), meta=np.ndarray>
#   * time_counter   (time_counter) datetime64[ns] 2010-02-01T00:30:00 ... 2010...
# Dimensions without coordinates: x, y
# Data variables:
#     fmask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     qt_oce         (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     somecrty       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sometauy       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sosaline       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sossheig       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sosstsst       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sowaflup       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sozocrtx       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sozotaux       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     tmask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     umask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     vmask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>

# %%
name_ssh_mod = 'sossheig'
name_lsm_mod = 'tmask' 
l_griddist = False

# %%
from intake import open_catalog
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean/altimetry.yaml")
dssat  = cat["al"].to_dask()

# %%
dssat
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 34340107)
# Coordinates:
#     latitude        (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     longitude       (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#   * time            (time) datetime64[ns] 2013-03-14T05:44:50.445185024 ... 2...
# Data variables:
#     cycle           (time) int16 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     dac             (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     lwe             (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     mdt             (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     ocean_tide      (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     sla_filtered    (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     sla_unfiltered  (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     track           (time) int16 dask.array<chunksize=(34340107,), meta=np.ndarray>
# Attributes:
#     Conventions:               CF-1.6
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     cdm_data_type:             Swath
#     comment:                   Sea surface height measured by altimeters refe...
#     contact:                   servicedesk.cmems@mercator-ocean.eu
#     creator_email:             servicedesk.cmems@mercator-ocean.eu
#     creator_name:              CMEMS - Sea Level Thematic Assembly Center
#     creator_url:               http://marine.copernicus.eu
#     history:                   2019-02-20T19:39:52Z: Creation
#     institution:               CLS, CNES
#     keywords:                  Oceans > Ocean Topography > Sea Surface Height
#     keywords_vocabulary:       NetCDF COARDS Climate and Forecast Standard Names
#     license:                   http://marine.copernicus.eu/web/27-service-com...
#     platform:                  Altika
#     processing_level:          L3
#     product_version:           2019
#     project:                   COPERNICUS MARINE ENVIRONMENT MONITORING SERVI...
#     references:                http://marine.copernicus.eu
#     software_version:          6.2_DUACS_DT2018_baseline
#     source:                    Altika measurements
#     ssalto_duacs_comment:      The reference mission used for the altimeter i...
#     standard_name_vocabulary:  NetCDF Climate and Forecast (CF) Metadata Conv...
#     summary:                   SSALTO/DUACS Delayed-Time Level-3 sea surface ...
#     title:                     DT Altika Global Ocean Along track SSALTO/DUAC...

# %%
name_ssh_sat='sla_unfiltered'

# %% [markdown]
# ## Time overlap between model and satellite ?
# Assume that model is less than 1 year, satellite has at least one whole year, we take the overlapping period without considering which year is this

# %%
    (date1,date2), (Nts,Ntm) = GetTimeOverlap( dssat , dsmod )
    print(' *** Time overlap between model and satellite in UNIX epoch time: it1, it2',date1,'--',date2)
# Out:
#  *** Time overlap between model and satellite in UNIX epoch time: it1, it2 2014-02-01 -- 2014-04-30

# %% [markdown]
# ## Create object `ModelGrid` containing all the model (aka _source_) 2D+T domain grid info

# %%
  
    ModelGrid = ModGrid( dsmod, date1 , date2 , dsmod, name_lsm_mod, distorded_grid=False )
# Out:
#  *** what we use to define model land-sea mask:
#     => "tmask" in dataset
#
#  *** Skipping computation of angle distortion of the model grid! ("-D" option not invoked)...
#
#  *** About model gridded (source) domain:
#      * shape =  (763, 611)
#      * horizontal resolution:  0.016657295  degrees or  1.8507920147292316  km
#      * Is this a global domain w.r.t longitude:  False
#        ==> this is a regional domain
#        ==> working in the [0:360] frame...
#      * lon_min, lon_max =  281.99 292.17
#      * lat_min, lat_max =  30.01 40.01
#      * should we pay attention to possible STRONG local distorsion in the grid:  False
#      * number of time records of interest for the interpolation to come:  2136
#        ==> time record dates: 2014-02-01 to 2014-04-30, included

# %%
SatelliteTrack = SatTrack( dssat, date1, date2, name_ssh_sat, Np=Nts, \
                              domain_bounds=ModelGrid.domain_bounds, l_0_360=ModelGrid.l360 )
# Out:
#  *** [SatTrack()] Analyzing the time vector in dataset ...
#
#  *** About satellite track (target) domain:
#      * number of time records of interest for the interpolation to come:  10236
#        ==> time record indices: 14883510 to 19033581, included
#
#        separated in 86 tracks

# %%
def process_one_track(track):
    tt = "{:02d}".format(track)
    Solution0 = Model2SatTrack( ModelGrid, name_ssh_mod, SatelliteTrack, name_ssh_sat, track )
    c1     = 'Model SSH interpolated in space (' ; c2=') and time on satellite track'
    vvar   = [ 'latitude', 'longitude', name_ssh_mod+'_np'   , name_ssh_mod+'_bl' , name_ssh_sat          , 'distance'                            ]
    vunits = [ 'deg.N'   , 'deg.E'    ,          'm'         ,     'm'            ,    'm'                ,    'km'                               ]
    vlongN = [ 'Latitude', 'Longitude', c1+'nearest-point'+c2,  c1+'bilinear'+c2  , 'Input satellite data', 'Cumulated distance from first point' ]
    iw = SaveTimeSeries( Solution0.time, \
                             nmp.array( [Solution0.lat, Solution0.lon, Solution0.ssh_mod_np,
                                         Solution0.ssh_mod, Solution0.ssh_sat, Solution0.distance] ), \
                             vvar, 'result_'+str(tt)+'.nc', time_units='',\
                             vunits=vunits, vlnm=vlongN, missing_val=rmissval )
    return Solution0

# %%
result = process_one_track(27)
# Out:
#  *** "found" distance criterion when searching for nearest point on model grid is  1.3880940110469238  km
#
#  *** Will use zoom boxes of width of 271 points for 1st attempts of nearest-point location...
#
#
#  *** Finding nearest points on source (model) grid... (rd_found_km, np_box_r = 1.3880940110469238 135 )
#       +++ Treated point: 1/173
#           ==> Sat. coordinates:     40.002 286.099
#           ==> Model nearest point:  40.007 292.013  ( -1 -1 )
#       +++ Treated point: 2/173
#           ==> Sat. coordinates:     39.944 286.08
#           ==> Model nearest point:  40.007 292.013  ( -1 -1 )
#       +++ Treated point: 3/173
#           ==> Sat. coordinates:     39.887 286.062
#           ==> Model nearest point:  40.007 292.013  ( -1 -1 )
#       +++ Treated point: 4/173
#           ==> Sat. coordinates:     39.829 286.043
#           ==> Model nearest point:  39.83 286.04  ( 758 251 )
#       +++ Treated point: 5/173
#           ==> Sat. coordinates:     39.772 286.024
#           ==> Model nearest point:  39.771 286.026  ( 753 250 )
#       +++ Treated point: 6/173
#           ==> Sat. coordinates:     39.714 286.005
#           ==> Model nearest point:  39.712 286.011  ( 748 249 )
#       +++ Treated point: 7/173
#           ==> Sat. coordinates:     39.657 285.987
#           ==> Model nearest point:  39.652 285.98  ( 743 247 )
#       +++ Treated point: 8/173
#           ==> Sat. coordinates:     39.599 285.968
#           ==> Model nearest point:  39.605 285.965  ( 739 246 )
#       +++ Treated point: 9/173
#           ==> Sat. coordinates:     39.542 285.949
#           ==> Model nearest point:  39.545 285.95  ( 734 245 )
#       +++ Treated point: 10/173
#           ==> Sat. coordinates:     39.484 285.931
#           ==> Model nearest point:  39.486 285.936  ( 729 244 )
#       +++ Treated point: 11/173
#           ==> Sat. coordinates:     39.427 285.912
#           ==> Model nearest point:  39.426 285.905  ( 724 242 )
#       +++ Treated point: 12/173
#           ==> Sat. coordinates:     39.369 285.893
#           ==> Model nearest point:  39.366 285.89  ( 719 241 )
#       +++ Treated point: 13/173
#           ==> Sat. coordinates:     39.311 285.875
#           ==> Model nearest point:  39.307 285.875  ( 714 240 )
#       +++ Treated point: 14/173
#           ==> Sat. coordinates:     39.254 285.856
#           ==> Model nearest point:  39.259 285.86  ( 710 239 )
#       +++ Treated point: 15/173
#           ==> Sat. coordinates:     39.196 285.838
#           ==> Model nearest point:  39.199 285.845  ( 705 238 )
#       +++ Treated point: 16/173
#           ==> Sat. coordinates:     39.139 285.819
#           ==> Model nearest point:  39.139 285.814  ( 700 236 )
#       +++ Treated point: 17/173
#           ==> Sat. coordinates:     39.081 285.801
#           ==> Model nearest point:  39.079 285.799  ( 695 235 )
#       +++ Treated point: 18/173
#           ==> Sat. coordinates:     39.024 285.782
#           ==> Model nearest point:  39.019 285.784  ( 690 234 )
#       +++ Treated point: 19/173
#           ==> Sat. coordinates:     38.966 285.764
#           ==> Model nearest point:  38.97 285.769  ( 686 233 )
#       +++ Treated point: 20/173
#           ==> Sat. coordinates:     38.909 285.746
#           ==> Model nearest point:  38.91 285.738  ( 681 231 )
#       +++ Treated point: 21/173
#           ==> Sat. coordinates:     38.851 285.727
#           ==> Model nearest point:  38.85 285.723  ( 676 230 )
#       +++ Treated point: 22/173
#           ==> Sat. coordinates:     38.793 285.709
#           ==> Model nearest point:  38.789 285.708  ( 671 229 )
#       +++ Treated point: 23/173
#           ==> Sat. coordinates:     38.736 285.69
#           ==> Model nearest point:  38.741 285.693  ( 667 228 )
#       +++ Treated point: 24/173
#           ==> Sat. coordinates:     38.678 285.672
#           ==> Model nearest point:  38.68 285.678  ( 662 227 )
#       +++ Treated point: 25/173
#           ==> Sat. coordinates:     38.621 285.654
#           ==> Model nearest point:  38.62 285.646  ( 657 225 )
#       +++ Treated point: 26/173
#           ==> Sat. coordinates:     38.563 285.636
#           ==> Model nearest point:  38.559 285.632  ( 652 224 )
#       +++ Treated point: 27/173
#           ==> Sat. coordinates:     38.506 285.617
#           ==> Model nearest point:  38.51 285.616  ( 648 223 )
#       +++ Treated point: 28/173
#           ==> Sat. coordinates:     38.448 285.599
#           ==> Model nearest point:  38.45 285.601  ( 643 222 )
#       +++ Treated point: 29/173
#           ==> Sat. coordinates:     38.39 285.581
#           ==> Model nearest point:  38.389 285.586  ( 638 221 )
#       +++ Treated point: 30/173
#           ==> Sat. coordinates:     38.333 285.563
#           ==> Model nearest point:  38.328 285.555  ( 633 219 )
#       +++ Treated point: 31/173
#           ==> Sat. coordinates:     38.275 285.545
#           ==> Model nearest point:  38.279 285.539  ( 629 218 )
#       +++ Treated point: 32/173
#           ==> Sat. coordinates:     38.218 285.526
#           ==> Model nearest point:  38.218 285.524  ( 624 217 )
#       +++ Treated point: 33/173
#           ==> Sat. coordinates:     38.16 285.508
#           ==> Model nearest point:  38.157 285.509  ( 619 216 )
#       +++ Treated point: 34/173
#           ==> Sat. coordinates:     38.102 285.49
#           ==> Model nearest point:  38.108 285.494  ( 615 215 )
#       +++ Treated point: 35/173
#           ==> Sat. coordinates:     38.045 285.472
#           ==> Model nearest point:  38.047 285.479  ( 610 214 )
#       +++ Treated point: 36/173
#           ==> Sat. coordinates:     37.987 285.454
#           ==> Model nearest point:  37.985 285.447  ( 605 212 )
#       +++ Treated point: 37/173
#           ==> Sat. coordinates:     37.93 285.436
#           ==> Model nearest point:  37.924 285.432  ( 600 211 )
#       +++ Treated point: 38/173
#           ==> Sat. coordinates:     37.872 285.418
#           ==> Model nearest point:  37.875 285.416  ( 596 210 )
#       +++ Treated point: 39/173
#           ==> Sat. coordinates:     37.814 285.4
#           ==> Model nearest point:  37.813 285.401  ( 591 209 )
#       +++ Treated point: 40/173
#           ==> Sat. coordinates:     37.757 285.382
#           ==> Model nearest point:  37.752 285.386  ( 586 208 )
#       +++ Treated point: 41/173
#           ==> Sat. coordinates:     37.699 285.364
#           ==> Model nearest point:  37.702 285.371  ( 582 207 )
#       +++ Treated point: 42/173
#           ==> Sat. coordinates:     37.642 285.346
#           ==> Model nearest point:  37.64 285.339  ( 577 205 )
#       +++ Treated point: 43/173
#           ==> Sat. coordinates:     37.584 285.328
#           ==> Model nearest point:  37.579 285.324  ( 572 204 )
#       +++ Treated point: 44/173
#           ==> Sat. coordinates:     37.526 285.311
#           ==> Model nearest point:  37.529 285.308  ( 568 203 )
#       +++ Treated point: 45/173
#           ==> Sat. coordinates:     37.469 285.293
#           ==> Model nearest point:  37.467 285.293  ( 563 202 )
#       +++ Treated point: 46/173
#           ==> Sat. coordinates:     37.411 285.275
#           ==> Model nearest point:  37.405 285.278  ( 558 201 )
#       +++ Treated point: 47/173
#           ==> Sat. coordinates:     37.354 285.257
#           ==> Model nearest point:  37.356 285.262  ( 554 200 )
#       +++ Treated point: 48/173
#           ==> Sat. coordinates:     37.296 285.239
#           ==> Model nearest point:  37.293 285.247  ( 549 199 )
#       +++ Treated point: 49/173
#           ==> Sat. coordinates:     37.238 285.222
#           ==> Model nearest point:  37.243 285.215  ( 545 197 )
#       +++ Treated point: 50/173
#           ==> Sat. coordinates:     37.181 285.204
#           ==> Model nearest point:  37.181 285.199  ( 540 196 )
#       +++ Treated point: 51/173
#           ==> Sat. coordinates:     37.123 285.186
#           ==> Model nearest point:  37.119 285.184  ( 535 195 )
#       +++ Treated point: 52/173
#           ==> Sat. coordinates:     37.065 285.168
#           ==> Model nearest point:  37.069 285.168  ( 531 194 )
#       +++ Treated point: 53/173
#           ==> Sat. coordinates:     37.008 285.151
#           ==> Model nearest point:  37.007 285.153  ( 526 193 )
#       +++ Treated point: 54/173
#           ==> Sat. coordinates:     36.95 285.133
#           ==> Model nearest point:  36.944 285.138  ( 521 192 )
#       +++ Treated point: 55/173
#           ==> Sat. coordinates:     36.893 285.115
#           ==> Model nearest point:  36.894 285.122  ( 517 191 )
#       +++ Treated point: 56/173
#           ==> Sat. coordinates:     36.835 285.098
#           ==> Model nearest point:  36.831 285.09  ( 512 189 )
#       +++ Treated point: 57/173
#           ==> Sat. coordinates:     36.777 285.08
#           ==> Model nearest point:  36.781 285.074  ( 508 188 )
#       +++ Treated point: 58/173
#           ==> Sat. coordinates:     36.72 285.063
#           ==> Model nearest point:  36.718 285.059  ( 503 187 )
#       +++ Treated point: 59/173
#           ==> Sat. coordinates:     36.662 285.045
#           ==> Model nearest point:  36.668 285.043  ( 499 186 )
#       +++ Treated point: 60/173
#           ==> Sat. coordinates:     36.604 285.027
#           ==> Model nearest point:  36.605 285.028  ( 494 185 )
#       +++ Treated point: 61/173
#           ==> Sat. coordinates:     36.547 285.01
#           ==> Model nearest point:  36.542 285.012  ( 489 184 )
#       +++ Treated point: 62/173
#           ==> Sat. coordinates:     36.489 284.992
#           ==> Model nearest point:  36.491 284.997  ( 485 183 )
#       +++ Treated point: 63/173
#           ==> Sat. coordinates:     36.431 284.975
#           ==> Model nearest point:  36.428 284.981  ( 480 182 )
#       +++ Treated point: 64/173
#           ==> Sat. coordinates:     36.374 284.957
#           ==> Model nearest point:  36.378 284.965  ( 476 181 )
#       +++ Treated point: 65/173
#           ==> Sat. coordinates:     36.316 284.94
#           ==> Model nearest point:  36.314 284.933  ( 471 179 )
#       +++ Treated point: 66/173
#           ==> Sat. coordinates:     36.258 284.923
#           ==> Model nearest point:  36.263 284.917  ( 467 178 )
#       +++ Treated point: 67/173
#           ==> Sat. coordinates:     36.201 284.905
#           ==> Model nearest point:  36.2 284.902  ( 462 177 )
#       +++ Treated point: 68/173
#           ==> Sat. coordinates:     36.143 284.888
#           ==> Model nearest point:  36.149 284.886  ( 458 176 )
#       +++ Treated point: 69/173
#           ==> Sat. coordinates:     36.085 284.87
#           ==> Model nearest point:  36.086 284.871  ( 453 175 )
#       +++ Treated point: 70/173
#           ==> Sat. coordinates:     36.028 284.853
#           ==> Model nearest point:  36.022 284.855  ( 448 174 )
#       +++ Treated point: 71/173
#           ==> Sat. coordinates:     35.97 284.836
#           ==> Model nearest point:  35.971 284.839  ( 444 173 )
#       +++ Treated point: 72/173
#           ==> Sat. coordinates:     35.912 284.818
#           ==> Model nearest point:  35.907 284.824  ( 439 172 )
#       +++ Treated point: 73/173
#           ==> Sat. coordinates:     35.855 284.801
#           ==> Model nearest point:  35.856 284.808  ( 435 171 )
#       +++ Treated point: 74/173
#           ==> Sat. coordinates:     35.797 284.784
#           ==> Model nearest point:  35.792 284.792  ( 430 170 )
#       +++ Treated point: 75/173
#           ==> Sat. coordinates:     35.739 284.767
#           ==> Model nearest point:  35.741 284.76  ( 426 168 )
#       +++ Treated point: 76/173
#           ==> Sat. coordinates:     35.682 284.749
#           ==> Model nearest point:  35.677 284.744  ( 421 167 )
#       +++ Treated point: 77/173
#           ==> Sat. coordinates:     35.624 284.732
#           ==> Model nearest point:  35.626 284.728  ( 417 166 )
#       +++ Treated point: 78/173
#           ==> Sat. coordinates:     35.566 284.715
#           ==> Model nearest point:  35.562 284.712  ( 412 165 )
#       +++ Treated point: 79/173
#           ==> Sat. coordinates:     35.509 284.698
#           ==> Model nearest point:  35.51 284.697  ( 408 164 )
#       +++ Treated point: 80/173
#           ==> Sat. coordinates:     35.451 284.681
#           ==> Model nearest point:  35.446 284.681  ( 403 163 )
#       +++ Treated point: 81/173
#           ==> Sat. coordinates:     35.393 284.664
#           ==> Model nearest point:  35.394 284.665  ( 399 162 )
#       +++ Treated point: 82/173
#           ==> Sat. coordinates:     35.335 284.646
#           ==> Model nearest point:  35.33 284.649  ( 394 161 )
#       +++ Treated point: 83/173
#           ==> Sat. coordinates:     35.278 284.629
#           ==> Model nearest point:  35.278 284.633  ( 390 160 )
#       +++ Treated point: 84/173
#           ==> Sat. coordinates:     35.22 284.612
#           ==> Model nearest point:  35.214 284.618  ( 385 159 )
#       +++ Treated point: 85/173
#           ==> Sat. coordinates:     35.162 284.595
#           ==> Model nearest point:  35.162 284.602  ( 381 158 )
#       +++ Treated point: 86/173
#           ==> Sat. coordinates:     35.105 284.578
#           ==> Model nearest point:  35.11 284.586  ( 377 157 )
#       +++ Treated point: 87/173
#           ==> Sat. coordinates:     35.047 284.561
#           ==> Model nearest point:  35.045 284.553  ( 372 155 )
#       +++ Treated point: 88/173
#           ==> Sat. coordinates:     34.989 284.544
#           ==> Model nearest point:  34.993 284.537  ( 368 154 )
#       +++ Treated point: 89/173
#           ==> Sat. coordinates:     34.932 284.527
#           ==> Model nearest point:  34.928 284.521  ( 363 153 )
#       +++ Treated point: 90/173
#           ==> Sat. coordinates:     34.874 284.51
#           ==> Model nearest point:  34.876 284.505  ( 359 152 )
#       +++ Treated point: 91/173
#           ==> Sat. coordinates:     34.816 284.493
#           ==> Model nearest point:  34.811 284.49  ( 354 151 )
#       +++ Treated point: 92/173
#           ==> Sat. coordinates:     34.758 284.476
#           ==> Model nearest point:  34.759 284.474  ( 350 150 )
#       +++ Treated point: 93/173
#           ==> Sat. coordinates:     34.701 284.459
#           ==> Model nearest point:  34.707 284.458  ( 346 149 )
#       +++ Treated point: 94/173
#           ==> Sat. coordinates:     34.643 284.442
#           ==> Model nearest point:  34.642 284.442  ( 341 148 )
#       +++ Treated point: 95/173
#           ==> Sat. coordinates:     34.585 284.426
#           ==> Model nearest point:  34.59 284.426  ( 337 147 )
#       +++ Treated point: 96/173
#           ==> Sat. coordinates:     34.528 284.409
#           ==> Model nearest point:  34.524 284.41  ( 332 146 )
#       +++ Treated point: 97/173
#           ==> Sat. coordinates:     34.47 284.392
#           ==> Model nearest point:  34.472 284.394  ( 328 145 )
#       +++ Treated point: 98/173
#           ==> Sat. coordinates:     34.412 284.375
#           ==> Model nearest point:  34.406 284.378  ( 323 144 )
#       +++ Treated point: 99/173
#           ==> Sat. coordinates:     34.354 284.358
#           ==> Model nearest point:  34.354 284.362  ( 319 143 )
#       +++ Treated point: 100/173
#           ==> Sat. coordinates:     34.297 284.341
#           ==> Model nearest point:  34.301 284.346  ( 315 142 )
#       +++ Treated point: 101/173
#           ==> Sat. coordinates:     34.239 284.325
#           ==> Model nearest point:  34.236 284.33  ( 310 141 )
#       +++ Treated point: 102/173
#           ==> Sat. coordinates:     34.181 284.308
#           ==> Model nearest point:  34.183 284.314  ( 306 140 )
#       +++ Treated point: 103/173
#           ==> Sat. coordinates:     34.123 284.291
#           ==> Model nearest point:  34.117 284.298  ( 301 139 )
#       +++ Treated point: 104/173
#           ==> Sat. coordinates:     34.066 284.274
#           ==> Model nearest point:  34.065 284.282  ( 297 138 )
#       +++ Treated point: 105/173
#           ==> Sat. coordinates:     34.008 284.258
#           ==> Model nearest point:  34.012 284.266  ( 293 137 )
#       +++ Treated point: 106/173
#           ==> Sat. coordinates:     33.95 284.241
#           ==> Model nearest point:  33.946 284.233  ( 288 135 )
#       +++ Treated point: 107/173
#           ==> Sat. coordinates:     33.892 284.224
#           ==> Model nearest point:  33.893 284.217  ( 284 134 )
#       +++ Treated point: 108/173
#           ==> Sat. coordinates:     33.835 284.208
#           ==> Model nearest point:  33.84 284.201  ( 280 133 )
#       +++ Treated point: 109/173
#           ==> Sat. coordinates:     33.777 284.191
#           ==> Model nearest point:  33.773 284.185  ( 275 132 )
#       +++ Treated point: 110/173
#           ==> Sat. coordinates:     33.719 284.174
#           ==> Model nearest point:  33.72 284.169  ( 271 131 )
#       +++ Treated point: 111/173
#           ==> Sat. coordinates:     33.662 284.158
#           ==> Model nearest point:  33.667 284.153  ( 267 130 )
#       +++ Treated point: 112/173
#           ==> Sat. coordinates:     33.604 284.141
#           ==> Model nearest point:  33.601 284.137  ( 262 129 )
#       +++ Treated point: 113/173
#           ==> Sat. coordinates:     33.546 284.125
#           ==> Model nearest point:  33.548 284.12  ( 258 128 )
#       +++ Treated point: 114/173
#           ==> Sat. coordinates:     33.488 284.108
#           ==> Model nearest point:  33.494 284.104  ( 254 127 )
#       +++ Treated point: 115/173
#           ==> Sat. coordinates:     33.43 284.091
#           ==> Model nearest point:  33.428 284.088  ( 249 126 )
#       +++ Treated point: 116/173
#           ==> Sat. coordinates:     33.373 284.075
#           ==> Model nearest point:  33.374 284.072  ( 245 125 )
#       +++ Treated point: 117/173
#           ==> Sat. coordinates:     33.315 284.058
#           ==> Model nearest point:  33.321 284.056  ( 241 124 )
#       +++ Treated point: 118/173
#           ==> Sat. coordinates:     33.257 284.042
#           ==> Model nearest point:  33.254 284.04  ( 236 123 )
#       +++ Treated point: 119/173
#           ==> Sat. coordinates:     33.199 284.025
#           ==> Model nearest point:  33.201 284.024  ( 232 122 )
#       +++ Treated point: 120/173
#           ==> Sat. coordinates:     33.142 284.009
#           ==> Model nearest point:  33.147 284.007  ( 228 121 )
#       +++ Treated point: 121/173
#           ==> Sat. coordinates:     33.084 283.993
#           ==> Model nearest point:  33.08 283.991  ( 223 120 )
#       +++ Treated point: 122/173
#           ==> Sat. coordinates:     33.026 283.976
#           ==> Model nearest point:  33.026 283.975  ( 219 119 )
#       +++ Treated point: 123/173
#           ==> Sat. coordinates:     32.968 283.96
#           ==> Model nearest point:  32.973 283.959  ( 215 118 )
#       +++ Treated point: 124/173
#           ==> Sat. coordinates:     32.911 283.943
#           ==> Model nearest point:  32.905 283.943  ( 210 117 )
#       +++ Treated point: 125/173
#           ==> Sat. coordinates:     32.853 283.927
#           ==> Model nearest point:  32.851 283.926  ( 206 116 )
#       +++ Treated point: 126/173
#           ==> Sat. coordinates:     32.795 283.911
#           ==> Model nearest point:  32.798 283.91  ( 202 115 )
#       +++ Treated point: 127/173
#           ==> Sat. coordinates:     32.737 283.894
#           ==> Model nearest point:  32.744 283.894  ( 198 114 )
#       +++ Treated point: 128/173
#           ==> Sat. coordinates:     32.679 283.878
#           ==> Model nearest point:  32.676 283.878  ( 193 113 )
#       +++ Treated point: 129/173
#           ==> Sat. coordinates:     32.622 283.862
#           ==> Model nearest point:  32.622 283.862  ( 189 112 )
#       +++ Treated point: 130/173
#           ==> Sat. coordinates:     32.564 283.845
#           ==> Model nearest point:  32.568 283.845  ( 185 111 )
#       +++ Treated point: 131/173
#           ==> Sat. coordinates:     32.506 283.829
#           ==> Model nearest point:  32.5 283.829  ( 180 110 )
#       +++ Treated point: 132/173
#           ==> Sat. coordinates:     32.448 283.813
#           ==> Model nearest point:  32.446 283.813  ( 176 109 )
#       +++ Treated point: 133/173
#           ==> Sat. coordinates:     32.391 283.796
#           ==> Model nearest point:  32.392 283.797  ( 172 108 )
#       +++ Treated point: 134/173
#           ==> Sat. coordinates:     32.333 283.78
#           ==> Model nearest point:  32.338 283.78  ( 168 107 )
#       +++ Treated point: 135/173
#           ==> Sat. coordinates:     32.275 283.764
#           ==> Model nearest point:  32.27 283.764  ( 163 106 )
#       +++ Treated point: 136/173
#           ==> Sat. coordinates:     32.217 283.748
#           ==> Model nearest point:  32.215 283.748  ( 159 105 )
#       +++ Treated point: 137/173
#           ==> Sat. coordinates:     32.159 283.732
#           ==> Model nearest point:  32.161 283.731  ( 155 104 )
#       +++ Treated point: 138/173
#           ==> Sat. coordinates:     32.102 283.715
#           ==> Model nearest point:  32.106 283.715  ( 151 103 )
#       +++ Treated point: 139/173
#           ==> Sat. coordinates:     32.044 283.699
#           ==> Model nearest point:  32.038 283.699  ( 146 102 )
#       +++ Treated point: 140/173
#           ==> Sat. coordinates:     31.986 283.683
#           ==> Model nearest point:  31.983 283.683  ( 142 101 )
#       +++ Treated point: 141/173
#           ==> Sat. coordinates:     31.928 283.667
#           ==> Model nearest point:  31.929 283.666  ( 138 100 )
#       +++ Treated point: 142/173
#           ==> Sat. coordinates:     31.87 283.651
#           ==> Model nearest point:  31.874 283.65  ( 134 99 )
#       +++ Treated point: 143/173
#           ==> Sat. coordinates:     31.813 283.635
#           ==> Model nearest point:  31.819 283.634  ( 130 98 )
#       +++ Treated point: 144/173
#           ==> Sat. coordinates:     31.755 283.619
#           ==> Model nearest point:  31.751 283.617  ( 125 97 )
#       +++ Treated point: 145/173
#           ==> Sat. coordinates:     31.697 283.603
#           ==> Model nearest point:  31.696 283.601  ( 121 96 )
#       +++ Treated point: 146/173
#           ==> Sat. coordinates:     31.639 283.587
#           ==> Model nearest point:  31.641 283.585  ( 117 95 )
#       +++ Treated point: 147/173
#           ==> Sat. coordinates:     31.581 283.57
#           ==> Model nearest point:  31.586 283.568  ( 113 94 )
#       +++ Treated point: 148/173
#           ==> Sat. coordinates:     31.524 283.554
#           ==> Model nearest point:  31.517 283.552  ( 108 93 )
#       +++ Treated point: 149/173
#           ==> Sat. coordinates:     31.466 283.538
#           ==> Model nearest point:  31.462 283.536  ( 104 92 )
#       +++ Treated point: 150/173
#           ==> Sat. coordinates:     31.408 283.522
#           ==> Model nearest point:  31.407 283.519  ( 100 91 )
#       +++ Treated point: 151/173
#           ==> Sat. coordinates:     31.35 283.506
#           ==> Model nearest point:  31.352 283.503  ( 96 90 )
#       +++ Treated point: 152/173
#           ==> Sat. coordinates:     31.292 283.49
#           ==> Model nearest point:  31.297 283.486  ( 92 89 )
#       +++ Treated point: 153/173
#           ==> Sat. coordinates:     31.234 283.475
#           ==> Model nearest point:  31.241 283.47  ( 88 88 )
#       +++ Treated point: 154/173
#           ==> Sat. coordinates:     31.177 283.459
#           ==> Model nearest point:  31.172 283.454  ( 83 87 )
#       +++ Treated point: 155/173
#           ==> Sat. coordinates:     31.119 283.443
#           ==> Model nearest point:  31.117 283.437  ( 79 86 )
#       +++ Treated point: 156/173
#           ==> Sat. coordinates:     31.061 283.427
#           ==> Model nearest point:  31.061 283.421  ( 75 85 )
#       +++ Treated point: 157/173
#           ==> Sat. coordinates:     31.003 283.411
#           ==> Model nearest point:  31.006 283.405  ( 71 84 )
#       +++ Treated point: 158/173
#           ==> Sat. coordinates:     30.945 283.395
#           ==> Model nearest point:  30.95 283.388  ( 67 83 )
#       +++ Treated point: 159/173
#           ==> Sat. coordinates:     30.887 283.379
#           ==> Model nearest point:  30.881 283.372  ( 62 82 )
#       +++ Treated point: 160/173
#           ==> Sat. coordinates:     30.83 283.363
#           ==> Model nearest point:  30.825 283.355  ( 58 81 )
#       +++ Treated point: 161/173
#           ==> Sat. coordinates:     30.772 283.347
#           ==> Model nearest point:  30.77 283.356  ( 54 81 )
#       +++ Treated point: 162/173
#           ==> Sat. coordinates:     30.714 283.332
#           ==> Model nearest point:  30.714 283.339  ( 50 80 )
#       +++ Treated point: 163/173
#           ==> Sat. coordinates:     30.656 283.316
#           ==> Model nearest point:  30.658 283.323  ( 46 79 )
#       +++ Treated point: 164/173
#           ==> Sat. coordinates:     30.598 283.3
#           ==> Model nearest point:  30.602 283.306  ( 42 78 )
#       +++ Treated point: 165/173
#           ==> Sat. coordinates:     30.54 283.284
#           ==> Model nearest point:  30.547 283.29  ( 38 77 )
#       +++ Treated point: 166/173
#           ==> Sat. coordinates:     30.483 283.268
#           ==> Model nearest point:  30.477 283.274  ( 33 76 )
#       +++ Treated point: 167/173
#           ==> Sat. coordinates:     30.425 283.253
#           ==> Model nearest point:  30.421 283.257  ( 29 75 )
#       +++ Treated point: 168/173
#           ==> Sat. coordinates:     30.367 283.237
#           ==> Model nearest point:  30.365 283.241  ( 25 74 )
#       +++ Treated point: 169/173
#           ==> Sat. coordinates:     30.309 283.221
#           ==> Model nearest point:  30.309 283.224  ( 21 73 )
#       +++ Treated point: 170/173
#           ==> Sat. coordinates:     30.251 283.205
#           ==> Model nearest point:  30.253 283.208  ( 17 72 )
#       +++ Treated point: 171/173
#           ==> Sat. coordinates:     30.193 283.19
#           ==> Model nearest point:  30.196 283.191  ( 13 71 )
#       +++ Treated point: 172/173
#           ==> Sat. coordinates:     30.136 283.174
#           ==> Model nearest point:  30.14 283.175  ( 9 70 )
#       +++ Treated point: 173/173
#           ==> Sat. coordinates:     30.078 283.158
#           ==> Model nearest point:  30.084 283.158  ( 5 69 )
#      ***    Done! ***
#
#   *** Determining source meshes...
#      ***    Done! ***
#
#   *** Computing bilinear weights...
#      ***    Done! ***
#
#
#  *** Starting space-time interpolation of model data onto the 173 selected track points...
#       jt = 06930 => satelite time = 2014-04-03T23:28:31.656918016
#       jt = 06931 => satelite time = 2014-04-03T23:28:32.636918016
#       jt = 06932 => satelite time = 2014-04-03T23:28:33.616918016
#       jt = 06933 => satelite time = 2014-04-03T23:28:34.596918016
#       jt = 06934 => satelite time = 2014-04-03T23:28:35.576918016
#       jt = 06935 => satelite time = 2014-04-03T23:28:36.556918016
#       jt = 06936 => satelite time = 2014-04-03T23:28:37.536918016
#       jt = 06937 => satelite time = 2014-04-03T23:28:38.516918016
#       jt = 06938 => satelite time = 2014-04-03T23:28:39.496918016
#       jt = 06939 => satelite time = 2014-04-03T23:28:40.476918016
#       jt = 06940 => satelite time = 2014-04-03T23:28:41.456918016
#       jt = 06941 => satelite time = 2014-04-03T23:28:42.436918016
#       jt = 06942 => satelite time = 2014-04-03T23:28:43.416918016
#       jt = 06943 => satelite time = 2014-04-03T23:28:44.396918016
#       jt = 06944 => satelite time = 2014-04-03T23:28:45.376918016
#       jt = 06945 => satelite time = 2014-04-03T23:28:46.356918016
#       jt = 06946 => satelite time = 2014-04-03T23:28:47.336918016
#       jt = 06947 => satelite time = 2014-04-03T23:28:48.316918016
#       jt = 06948 => satelite time = 2014-04-03T23:28:49.296918016
#       jt = 06949 => satelite time = 2014-04-03T23:28:50.276918016
#       jt = 06950 => satelite time = 2014-04-03T23:28:51.256918016
#       jt = 06951 => satelite time = 2014-04-03T23:28:52.236918016
#       jt = 06952 => satelite time = 2014-04-03T23:28:53.216918016
#       jt = 06953 => satelite time = 2014-04-03T23:28:54.196918016
#       jt = 06954 => satelite time = 2014-04-03T23:28:55.176918016
#       jt = 07092 => satelite time = 2014-04-03T23:31:10.416918016
#       jt = 07093 => satelite time = 2014-04-03T23:31:11.396918016
#       jt = 07094 => satelite time = 2014-04-03T23:31:12.376918016
#       jt = 07095 => satelite time = 2014-04-03T23:31:13.356918016
#       jt = 07096 => satelite time = 2014-04-03T23:31:14.336918016
#       jt = 07097 => satelite time = 2014-04-03T23:31:15.316918016
#       jt = 07098 => satelite time = 2014-04-03T23:31:16.296918016
#       jt = 07099 => satelite time = 2014-04-03T23:31:17.276918016
#       jt = 07100 => satelite time = 2014-04-03T23:31:18.256918016
#       jt = 07101 => satelite time = 2014-04-03T23:31:19.236918016
#       jt = 07102 => satelite time = 2014-04-03T23:31:20.216918016
#  *** Space-time interpolation done!
#
#
#  *** Time report:
#      - Construction of the source-target bilinear mapping took: 2.0 s
#      - Interpolation of model data on the 173 satellite points took: 283.0 s
#
#
#  *** About to write file "result_27.nc"...
#  *** "result_27.nc" successfully written!

# %%
result.ssh_sat
# Out:
# masked_array(data=[ 0.162,  0.166,  0.138,  0.151,  0.171,  0.176,  0.156,
#                     0.134,  0.126,  0.147,  0.105,  0.114,  0.119,  0.138,
#                     0.113,  0.117,  0.118,  0.121,  0.135,  0.132,  0.116,
#                     0.113,  0.12 ,  0.126,  0.121,  0.121,  0.103,  0.103,
#                     0.126,  0.086,  0.078,  0.081,  0.096,  0.086,  0.102,
#                     0.116,  0.136,  0.12 ,  0.11 ,  0.142,  0.181,  0.177,
#                     0.149,  0.138,  0.124,  0.132,  0.145,  0.108,  0.091,
#                     0.115,  0.131,  0.099,  0.101,  0.086,  0.096,  0.103,
#                     0.11 ,  0.115,  0.069,  0.085,  0.093,  0.106,  0.107,
#                     0.124,  0.119,  0.087,  0.089,  0.116,  0.106,  0.112,
#                     0.107,  0.097,  0.087,  0.094,  0.102,  0.081,  0.092,
#                     0.098,  0.069,  0.069,  0.05 ,  0.069,  0.068,  0.062,
#                     0.071,  0.056,  0.076,  0.074,  0.068,  0.088,  0.072,
#                     0.077,  0.095,  0.083,  0.058,  0.063,  0.091,  0.083,
#                     0.041,  0.021,  0.029,  0.018,  0.005,  0.002, -0.003,
#                    -0.002, -0.017, -0.031,  0.181,  0.111,  0.152,  0.186,
#                     0.205,  0.211,  0.227,  0.256,  0.289,  0.329,  0.385,
#                     0.382,  0.357,  0.379,  0.391,  0.388,  0.368,  0.36 ,
#                     0.353,  0.331,  0.322,  0.327,  0.336,  0.33 ,  0.316,
#                     0.341,  0.339,  0.341,  0.326,  0.315,  0.303,  0.302,
#                     0.307,  0.297,  0.302,  0.303,  0.307,  0.308,  0.301,
#                     0.298,  0.294,  0.303,  0.31 ,  0.307,  0.298,  0.308,
#                     0.305,  0.294,  0.284,  0.309,  0.313,  0.308,  0.301,
#                     0.296,  0.303,  0.301,  0.299,  0.292,  0.292,  0.296,
#                     0.293,  0.287,  0.286,  0.28 ,  0.296],
#              mask=False,
#        fill_value=1e+20)
