# %%
import sys,os
from os import getenv
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Params

# %%
model = 'GIGATL'
region = '1'
season = 'aso'
name_mod = model+'-Region'+region+'-'+season
name_ssh_mod = 'zeta'
name_lsm_mod = 'salt' 
name_lat_mod = 'lat'
name_lon_mod = 'lon'
name_time_mod = 'ocean_time'
l_griddist = False

# %% [markdown]
# ## Data

# %%
import xarray as xr
import intake
import gcsfs

gcs = gcsfs.GCSFileSystem(requester_pays=True)

cat = intake.open_catalog('../SWOT-AdAC/catalog.yaml')
dsmod = cat[model](region=region,depth='surf', season=season).to_dask()

# %%
dsmod
# Out:
# <xarray.Dataset>
# Dimensions:     (eta_rho: 1489, eta_v: 1488, time: 2280, xi_rho: 1491, xi_u: 1490)
# Dimensions without coordinates: eta_rho, eta_v, time, xi_rho, xi_u
# Data variables: (12/13)
#     angle       (eta_rho, xi_rho) float32 dask.array<chunksize=(1489, 1491), meta=np.ndarray>
#     f           (eta_rho, xi_rho) float32 dask.array<chunksize=(1489, 1491), meta=np.ndarray>
#     h           (eta_rho, xi_rho) float32 dask.array<chunksize=(1489, 1491), meta=np.ndarray>
#     lat         (eta_rho, xi_rho) float32 dask.array<chunksize=(1489, 1491), meta=np.ndarray>
#     lon         (eta_rho, xi_rho) float32 dask.array<chunksize=(1489, 1491), meta=np.ndarray>
#     ocean_time  (time) float32 dask.array<chunksize=(24,), meta=np.ndarray>
#     ...          ...
#     pn          (eta_rho, xi_rho) float32 dask.array<chunksize=(1489, 1491), meta=np.ndarray>
#     salt        (time, eta_rho, xi_rho) float32 dask.array<chunksize=(24, 1489, 1491), meta=np.ndarray>
# ...

# %%
t=dsmod.ocean_time.values

# %%
t[0]
# Out:
# 933553700.0

# %%
t[1]
# Out:
# 933557400.0

# %%
(t[11]-t[10])/3600
# Out:
# 0.9955555555555555

# %%
(t[-1]-t[0])/3600./24
# Out:
# 94.95851851851852

# %%
31+30+28
# Out:
# 89

# %%
day0='2009-08-01'

# %%
from datetime import datetime as dtm
date = dtm.utcfromtimestamp(t[2])

# %%
print(date)
# Out:
# 1999-08-02 02:29:20

# %%
dsmod.ocean_time
# Out:
# <xarray.DataArray 'ocean_time' (time: 2280)>
# dask.array<open_dataset-79fcc859cbb0d105e7747e5f34457907ocean_time, shape=(2280,), dtype=float32, chunksize=(24,), chunktype=numpy.ndarray>
# Dimensions without coordinates: time

# %%
type(dsmod.ocean_time.values[0])
# Out:
# numpy.float32

# %%
import numpy as nmp
if type(dsmod.ocean_time.values[0]) == nmp.float32:
    print('yeah')
# Out:
# yeah

# %%
tt=t.astype(int)

# %%
date = dtm.utcfromtimestamp(nmp.array(tt))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_371193/1668213353.py in <module>
# ----> 1 date = dtm.utcfromtimestamp(nmp.array(tt))
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
date = dtm.utcfromtimestamp(t[0])
print(date)
# Out:
# 1999-08-02 00:28:48

# %%
date = dtm.fromtimestamp(t)[indices.astype(int)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_371193/508648752.py in <module>
# ----> 1 date = dtm.fromtimestamp(t)[indices.astype(int)]
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
tt=[]
for k in nmp.arange(len(t)):
    tt.append(dtm.utcfromtimestamp(t[k].astype(int)))

# %%
print(tt[0])
# Out:
# 1999-08-02 00:28:48

# %%
import datetime
date0=datetime(1970, 1, 1, tzinfo=tz.utc) + timedelta(seconds=t[0])
print(date0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_371193/1794682411.py in <module>
#       1 import datetime
# ----> 2 date0=datetime(1970, 1, 1, tzinfo=tz.utc) + timedelta(seconds=t[0])
#       3 print(date0)
#
# TypeError: 'module' object is not callable

# %%
from datetime import timezone as tz

# %%
tz.utc
# Out:
# datetime.timezone.utc

# %%
datetime(1970, 1, 1, tzinfo=tz.utc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_371193/490091756.py in <module>
# ----> 1 datetime(1970, 1, 1, tzinfo=tz.utc)
#
# TypeError: 'module' object is not callable

# %%
datetime.timedelta(seconds=t[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_371193/593136640.py in <module>
# ----> 1 datetime.timedelta(seconds=t[0])
#
# TypeError: unsupported type for timedelta seconds component: numpy.float32
