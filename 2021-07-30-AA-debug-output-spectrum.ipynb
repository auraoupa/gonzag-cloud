# %%
import xarray as xr
import sys
import glob
import numpy as nmp

# %%
fresults=sorted(glob.glob('results/result_??.nc'))
ds=xr.open_mfdataset(fresults,concat_dim='time',combine='nested')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 10021)
# Coordinates:
#   * time            (time) float64 1.392e+18 1.392e+18 ... 1.397e+18 1.397e+18
# Data variables:
#     latitude        (time) float64 dask.array<chunksize=(148,), meta=np.ndarray>
#     longitude       (time) float64 dask.array<chunksize=(148,), meta=np.ndarray>
#     sossheig_np     (time) float64 dask.array<chunksize=(148,), meta=np.ndarray>
#     sossheig_bl     (time) float64 dask.array<chunksize=(148,), meta=np.ndarray>
#     sla_unfiltered  (time) float64 dask.array<chunksize=(148,), meta=np.ndarray>
#     distance        (time) float64 dask.array<chunksize=(148,), meta=np.ndarray>
#     time_counter    (time) datetime64[ns] dask.array<chunksize=(148,), meta=np.ndarray>
# Attributes:
#     about:    Created with Gonzag package => https://github.com/brodeau/gonzag

# %%
ds.time_counter
# Out:
# <xarray.DataArray 'time_counter' (time: 10021)>
# dask.array<concatenate, shape=(10021,), dtype=datetime64[ns], chunksize=(173,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) float64 1.392e+18 1.392e+18 ... 1.397e+18 1.397e+18
# Attributes:
#     axis:           T
#     long_name:      Time of measurement
#     standard_name:  time

# %%
VT = ds.time

# %%
print(VT)
# Out:
# <xarray.DataArray 'time' (time: 10021)>
# array([1.391683e+18, 1.391683e+18, 1.391683e+18, ..., 1.396827e+18,
#        1.396827e+18, 1.396827e+18])
# Coordinates:
#   * time     (time) float64 1.392e+18 1.392e+18 ... 1.397e+18 1.397e+18
# Attributes:
#     axis:           T
#     long_name:      Time of measurement
#     standard_name:  time

# %%
VM=ds.sla_unfiltered

# %%
VM[3600:3700].values
# Out:
# array([ 0.102,  0.118,  0.12 ,  0.101,  0.121,  0.121,  0.102,  0.101,
#         0.095,  0.075,  0.069,  0.062,  0.026,  0.059,  0.054,  0.051,
#         0.064,  0.043,  0.057,  0.043,  0.042,  0.058,  0.07 ,  0.08 ,
#         0.094,  0.089,  0.098,  0.106,  0.11 ,  0.111,  0.116,  0.102,
#         0.096,  0.088,  0.091,  0.08 ,  0.045,  0.075,  0.043,  0.034,
#         0.026,  0.047,  0.048,  0.046,  0.06 ,  0.066,  0.082,  0.111,
#         0.117,  0.151,  0.161,  0.145,  0.259,  0.161,  0.115,  0.11 ,
#         0.056,  0.05 ,  0.105,  0.07 ,  0.079,  0.031,  0.017,    nan,
#           nan, -0.05 , -0.026,  0.008,  0.048,  0.093,  0.112,  0.119,
#         0.113,  0.095,  0.088,  0.091,  0.076,  0.091,  0.114,  0.138,
#         0.138,  0.118,  0.141,  0.124,  0.111,  0.136,  0.142,  0.131,
#         0.13 ,  0.124,  0.138,  0.16 ,  0.168,  0.186,  0.158,  0.151,
#         0.15 ,  0.137,  0.117,  0.124])

# %%
ii=nmp.where(nmp.isnan(VM.values)==1)

# %%
#   7748  7791  7816  7859  7898  7903  7908  8027  8076  8093  8094  8145
#   8168  8176  8225  8264  8313  8333  8374  8382  8422  8471  8540  8590
#   8593  8642  8761  8765  8814  8933  8938  8987  9027  9058  9080  9129
#   9134  9162  9183  9246  9250  9299  9368  9415  9464  9583  9636  9720
#   9734  9744  9793  9806  9855  9940  9954  9963  9981  9989 10012 10020]

# %%
print(len(ISeg_beg))
# Out:
# 240

# %%
ds.distance[12].values-ds.distance[11].values
# Out:
# 6.593076418648025

# %%
NbSeg, Nsl, IDEDSeg = SegmentSelection(ISeg_beg, ISeg_end, np_valid_seg=70)
# Out:
#  *** [SegmentSelection()]: Will use 24 segments with a fixed length of 100 points!
#      ==> 24 selected segments out of the 240 available (requested minimum length is 70 points)

# %%
IDseg=IDEDSeg
Vd=ds.distance
VS=ds.sossheig_bl
VM=ds.sla_unfiltered

# %%
    from scipy.signal import detrend, tukey
    #
    #
    NbS = IDseg.shape[0] ; # number of segments
    if ivrb>1: print(' *** [Process4FFT()] NbS = ', NbS)

    Nsl = IDseg[0,1]-IDseg[0,0]+1 ; # length of segments
    if ivrb>1: print(' *** [Process4FFT()] Nsl = ', Nsl)
    
    vs_s = nmp.zeros((NbS,Nsl))
    vs_m = nmp.zeros((NbS,Nsl))

# %%
NbS
# Out:
# 24

# %%
js=11

# %%
        it1 = IDseg[js,0]
        it2 = IDseg[js,1]

# %%
print(it1,it2)
# Out:
# 3600 3699

# %%
            dmean = nmp.mean(Vd[it1+1:it2+1].values-Vd[it1:it2].values)
            print(' *** [Process4FFT()]: Mean distance between two consecutive points is '+str(dmean)+' km\n')
            # Sample spacing in [km] (inverse of the sampling rate):
            dx_sample = nmp.round(dmean,3)
            print('     => will use a spatial sample spacing of '+str(dx_sample)+' km\n')

# %%
Vd[it1+1:it2+1].values

# %%
VS[it1:it2+1].values

# %%
dmean = nmp.mean(Vd[it1+1:it2+1].values-Vd[it1:it2].values)

# %%
print(dmean)

# %%
dx_sample = nmp.round(dmean,3)

# %%
dx_sample

# %%
        vs_s[js,:] = VS[it1:it2+1].values
        vs_m[js,:] = VM[it1:it2+1].values

# %%
            vs_s[js,:] = detrend(vs_s[js,:],type='linear')
            vs_m[js,:] = detrend(vs_m[js,:],type='linear')

# %%
        vs_s[js,:] = vs_s[js,:] - nmp.mean(vs_s[js,:])
        vs_m[js,:] = vs_m[js,:] - nmp.mean(vs_m[js,:])

# %%
            wdw =  tukey(Nsl,0.5)
            if js==0: print(' *** [Process4FFT()]: applying "Tukey" tappering...')
            vs_s[js,:] = vs_s[js,:]*wdw
            vs_m[js,:] = vs_m[js,:]*wdw

# %%
XPs, XPm, rdist_sample = Process4FFT( IDEDSeg, ds.distance, ds.sossheig_bl, ds.sla_unfiltered )

# %%
Kwn, PwSpc_s, PwSpc_m = ApplyFFT( IDEDSeg, XPs, XPm, rdist_sample )
